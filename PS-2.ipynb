# %%
import numpy as nump
import matplotlib.pyplot as plt
import pandas as ps

X=[1, 2, 3]
Y=[1, 3, 2]
plot.scatter(X, Y)

# %%
#Given Details
slope_curr = 0
intercept_curr = 0
learning_rate = 0.01
iterations = 1000

# %%
for i in range (iterations):
    sum1 = 0
    sum2 = 0
    for j in range(len(X)):
        sum1 += X[j] * (Y[j] - slope_curr*X[j] - intercept_curr)
        sum2 += Y[j] - slope_curr*X[j] - intercept_curr
    slope_gradient = -(2/len(X)) * sum1
    intercept_gradient = -(2/len(X)) * sum2
    slope_curr -= learning_rate * slope_gradient
    intercept_curr -= learning_rate * intercept_gradient
    y_predicted = [slope_curr*x + intercept_curr for x in X]
    plt.plot(X, y_predicted)
plt.scatter(X, Y)
y_predicted = [slope_curr*x + intercept_curr for x in X]
plt.plot(X, y_predicted)
plt.show()

# %%
X=[1,2]
Y=[1,3]
plt.scatter(X,Y)

# %%
slope_curr=0
intercept_curr=0
LR = 0.01
iterations = 10000

# %%
for i in range(iterations):
    sum1 = 0
    sum2 = 0
    for j in range(len(X)):
        sum1 += X[j] * (Y[j] - slope_curr*X[j] - intercept_curr)
        sum2 += Y[j] - slope_curr*X[j] - intercept_curr
    slope_gradient = -(2/len(X)) * sum1
    intercept_gradient = -(2/len(X)) * sum2
    slope_curr -= LR * slope_gradient
    intercept_curr -= LR * intercept_gradient
    y_predicted = [slope_curr*x + intercept_curr for x in X]
    plt.plot(X, y_predicted)
plt.scatter(X, Y)
y_predicted = [slope_curr*x + intercept_curr for x in X]
plt.plot(X, y_predicted)
plt.show()

# %%
plt.scatter(X, Y)
y_predicted = [slope_curr*x + intercept_curr for x in X]
plt.plot(X, y_predicted);
