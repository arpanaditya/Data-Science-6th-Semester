# %%
import random
import matplotlib.pyplot as mplot
import numpy as npy
import pandas as pd
import math
import collections

# %%
#q1
#Assigning values between 60 and 70 and randomly choosing 100 values within this range
datas = [i for i in range(60, 70)]
[datas.append(random.choice(datas)) for i in range(1000)]
print(datas)
# Out:
# [60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 61, 68, 64, 65, 69, 65, 65, 68, 64, 65, 68, 68, 65, 65, 65, 65, 65, 64, 65, 67, 69, 66, 68, 69, 69, 69, 61, 61, 69, 68, 64, 65, 61, 69, 64, 69, 64, 65, 64, 67, 69, 68, 65, 64, 68, 62, 67, 69, 66, 60, 69, 61, 65, 68, 68, 68, 68, 60, 65, 68, 65, 69, 69, 65, 66, 69, 69, 65, 69, 65, 61, 61, 66, 66, 66, 69, 65, 64, 61, 69, 65, 66, 67, 60, 64, 65, 64, 61, 69, 69, 64, 65, 69, 61, 61, 69, 68, 64, 65, 61, 68, 61, 65, 60, 64, 65, 65, 67, 61, 65, 60, 69, 69, 66, 67, 69, 68, 62, 61, 67, 68, 65, 69, 61, 68, 65, 65, 61, 63, 65, 67, 68, 69, 65, 60, 60, 65, 65, 65, 65, 61, 65, 65, 65, 69, 60, 65, 64, 64, 65, 66, 64, 69, 65, 65, 69, 65, 61, 62, 66, 68, 69, 65, 64, 69, 65, 64, 69, 65, 69, 69, 69, 68, 65, 68, 60, 68, 62, 69, 60, 69, 68, 64, 66, 69, 69, 61, 61, 68, 64, 60, 68, 64, 67, 66, 68, 65, 63, 64, 67, 69, 68, 65, 65, 69, 68, 61, 65, 69, 64, 65, 63, 63, 66, 69, 66, 68, 68, 66, 60, 64, 69, 68, 69, 63, 68, 65, 68, 68, 68, 65, 69, 68, 67, 69, 69, 63, 69, 61, 6
# ...

# %%
#Creating series to store values
dt = pd.Series(datas)
dt
# Out:
# 0       60
# 1       61
# 2       62
# 3       63
# 4       64
#         ..
# 1005    69
# 1006    69
# 1007    61
# 1008    65
# 1009    67
# Length: 1010, dtype: int64

# %%
#q2
#Calculating mean and standard deviation of the datas
mean = dt.mean()
print(f'Mean = {mean}')

std_deviation = dt.std()
print(f'Standard Deviation = {std_deviation}')
# Out:
# Mean = 65.45247524752476
# Standard Deviation = 2.7914315327201558

# %%
#q3
#Plotting histogram of the distribution
mplot.hist(datas, edgecolor='black')
mplot.title('Historgram of 1000 Random values between 60 and 70')
mplot.xlabel('Values')
mplot.ylabel('Frequency')
mplot.show()

# %%
#q4 and q5
sample = []
smean = []

#Choosing random values, adding them to sample[], calculating mean for each size of the list and storing it to smean[]
for i in range(30):
    for j in range(30):
        val = random.choice(datas)
        sample.append(val)
    temp = npy.mean(sample)
    smean.append(temp)
print(smean)
# Out:
# [66.36666666666666, 65.8, 65.94444444444444, 65.66666666666667, 65.68666666666667, 65.77222222222223, 65.80952380952381, 65.7875, 65.81481481481481, 65.80666666666667, 65.77878787878788, 65.72777777777777, 65.66666666666667, 65.67380952380952, 65.59555555555555, 65.64166666666667, 65.58823529411765, 65.57962962962964, 65.58771929824562, 65.595, 65.5904761904762, 65.57121212121213, 65.5536231884058, 65.5513888888889, 65.56533333333333, 65.59615384615384, 65.60246913580247, 65.61309523809524, 65.60689655172413, 65.6]

# %%
#q6

for i in range(470):
    for j in range(20):
        val = random.choice(datas)
        sample.append(val)
    temp = npy.mean(sample)
    smean.append(temp)
print(smean)
# Out:
# [66.36666666666666, 65.8, 65.94444444444444, 65.66666666666667, 65.68666666666667, 65.77222222222223, 65.80952380952381, 65.7875, 65.81481481481481, 65.80666666666667, 65.77878787878788, 65.72777777777777, 65.66666666666667, 65.67380952380952, 65.59555555555555, 65.64166666666667, 65.58823529411765, 65.57962962962964, 65.58771929824562, 65.595, 65.5904761904762, 65.57121212121213, 65.5536231884058, 65.5513888888889, 65.56533333333333, 65.59615384615384, 65.60246913580247, 65.61309523809524, 65.60689655172413, 65.6, 65.60108695652174, 65.60851063829787, 65.61458333333333, 65.60306122448979, 65.626, 65.60686274509804, 65.61346153846154, 65.61981132075472, 65.60833333333333, 65.59272727272727, 65.60089285714285, 65.59122807017543, 65.57586206896552, 65.56949152542373, 65.57916666666667, 65.57622950819672, 65.57903225806452, 65.58571428571429, 65.58828125, 65.59615384615384, 65.59924242424242, 65.61940298507463, 65.60514705882353, 65.59565217391304, 65.60785714285714, 65.60352112676057, 
# ...

# %%
#q7

mplot.hist(smean, edgecolor='black')
mplot.xlabel('Values')
mplot.ylabel('frequency')

mplot.show()

# %%
#q8

#Calculating mean and standard deviation of smean[]
print(f'Mean of smean[] = {npy.mean(smean)}')
print(f'Standard deviation of smean[] = {npy.std(smean)}')
# Out:
# Mean of smean[] = 65.51684911890136
# Standard deviation of smean[] = 0.07108557082795651

# %%
print(std_deviation/math.sqrt(30))
# Out:
# 0.5096433394006832
